# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from dl4cv.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `dl4cv/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `dl4cv/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the Softmax exercise: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs. Please first read the class description in the file, in particular note that for this exercise we use ReLU non-linearities.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from dl4cv.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# W2 max relative error: 3.440708e-09
# b1 max relative error: 1.555470e-09
# b2 max relative error: 3.865091e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the Softmax classifier. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the Softmax classifier. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from dl4cv.data_utils import load_CIFAR10
from dl4cv.vis_utils import visualize_cifar10

def get_CIFAR10_data(num_training=48000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. 
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'datasets/'
    X, y = load_CIFAR10(cifar10_dir)
    

    # Our training set will be the first num_train points from the original
    # training set.
    mask = range(num_training)
    X_train = X[mask]
    y_train = y[mask]
    
    
    # Our validation set will be num_validation points from the original
    # training set.
    mask = range(num_training, num_training + num_validation)
    X_val = X[mask]
    y_val = y[mask]
    
    # We use a small subset of the training set as our test set.
    mask = range(num_training + num_validation, num_training + num_validation + num_test)
    X_test = X[mask]
    y_test = y[mask]
    
    # We will also make a development set, which is a small subset of
    # the training set. This way the development cycle is faster.
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

    return X, y, X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_raw, y_raw, X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev= get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)

# visualize raw data
visualize_cifar10(X_raw, y_raw)
# Out:
# Train data shape:  (48000, 3072)
# Train labels shape:  (48000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302928
# iteration 100 / 1000: loss 2.302396
# iteration 200 / 1000: loss 2.297442
# iteration 300 / 1000: loss 2.253682
# iteration 400 / 1000: loss 2.202083
# iteration 500 / 1000: loss 2.141881
# iteration 600 / 1000: loss 2.162196
# iteration 700 / 1000: loss 1.976136
# iteration 800 / 1000: loss 2.111647
# iteration 900 / 1000: loss 2.005448
# Validation accuracy:  0.268

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.26 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplots(nrows=2, ncols=1)

plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')

plt.tight_layout()
plt.show()

# %%
from dl4cv.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    fig = plt.figure(figsize=(20,20))
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, number of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should aim to achieve a classification accuracy of greater than 48% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).
#
#
# **We highly encourage you to use this opportunity to get a feel for your machine learning system. Consider this kind of tuning as an essential part of getting the most out of your neural network**

# %%
from dl4cv.classifiers.neural_net import TwoLayerNet
best_net = None # store the best model into this 


input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
results = {}
best_val = -1
best_net = None
all_classifiers = []
learning_rates = [1e-8, 5e-8, 1e-7, 5e-7, 1e-6, 5e-6, 1e-5]
regularization_strengths = [1e-4, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4]

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        
        net = TwoLayerNet(input_size, hidden_size, num_classes)
        print('Train with learning rate {0} and regularization {1}'.format(learning_rate, regularization_strength))

        # Train the network
        stats = net.train(X_train, y_train, X_val, y_val,
                    num_iters=200, batch_size=200,
                    learning_rate=learning_rate,
                    learning_rate_decay=0.95,
                    reg=regularization_strength, 
                    verbose=True)
       
        
        # train to get loss and accuracy
        y_train_pred = np.mean(y_train == net.predict(X_train))
        y_val_pred = np.mean(y_val == net.predict(X_val))     
        results[(learning_rate, regularization_strength)] = (y_train_pred, y_val_pred)
        all_classifiers.append((net, y_val_pred))
        
        # save if best        
        if y_val_pred > best_val:
            print(':) BEST Validation Accuracy: ', y_val_pred)
            best_val = y_val_pred
            best_net = net

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################

# Print out results.
for (lr, reg) in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
          lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during validation: %f' % best_val)
# Out:
# Train with learning rate 1e-08 and regularization 0.0001
# iteration 0 / 200: loss 2.302574
# iteration 100 / 200: loss 2.302590
# :) BEST Validation Accuracy:  0.085
# Train with learning rate 1e-08 and regularization 0.001
# iteration 0 / 200: loss 2.302533
# iteration 100 / 200: loss 2.302566
# :) BEST Validation Accuracy:  0.129
# Train with learning rate 1e-08 and regularization 0.01
# iteration 0 / 200: loss 2.302623
# iteration 100 / 200: loss 2.302634
# Train with learning rate 1e-08 and regularization 0.1
# iteration 0 / 200: loss 2.302699
# iteration 100 / 200: loss 2.302690
# Train with learning rate 1e-08 and regularization 1
# iteration 0 / 200: loss 2.303359
# iteration 100 / 200: loss 2.303371
# Train with learning rate 1e-08 and regularization 10.0
# iteration 0 / 200: loss 2.310233
# iteration 100 / 200: loss 2.310221
# Train with learning rate 1e-08 and regularization 100.0
# iteration 0 / 200: loss 2.379868
# iteration 100 / 200: loss 2.379859
# Train with learning rate 1e-08 and regularization 1000.0
# iteration 0 / 200: loss 3.072323
# iteration 100 / 200: loss 3.070856
# :) BEST Validation Accuracy:  0.146
# Train with learning rate 1e-08 and regularization 10000.0
# iteration 0 / 200: loss 10.031175
# iteration 100 / 200: loss 9.885630
# Train with learning rate 5e-08 and regularization 0.0001
# iteration 0 / 200: loss 2.302573
# iteration 100 / 200: loss 2.302584
# Train with learning rate 5e-08 and regularization 0.001
# iteration 0 / 200: loss 2.302563
# iteration 100 / 200: loss 2.302589
# Train with learning rate 5e-08 and regularization 0.01
# iteration 0 / 200: loss 2.302585
# iteration 100 / 200: loss 2.302601
# Train with learning rate 5e-08 and regularization 0.1
# iteration 0 / 200: loss 2.302656
# iteration 100 / 200: loss 2.302646
# Train with learning rate 5e-08 and regularization 1
# iteration 0 / 200: loss 2.303327
# iteration 100 / 200: loss 2.303345
# :) BEST Validation Accuracy:  0.147
# Train with learning rate 5e-08 and regularization 10.0
# iteration 0 / 200: loss 2.310262
# iteration 100 / 200: loss 2.310264
# Train with learning rate 5e-08 and regularization 100.0
# iteration 0 / 200: loss 2.379656
# iteration 100 / 200: loss 2.379597
# Train with learning rate 5e-08 and regularization 1000.0
# iteration 0 / 200: loss 3.079126
# iteration 100 / 200: loss 3.071793
# Train with learning rate 5e-08 and regularization 10000.0
# iteration 0 / 200: loss 9.976227
# iteration 100 / 200: loss 9.280270
# Train with learning rate 1e-07 and regularization 0.0001
# iteration 0 / 200: loss 2.302603
# iteration 100 / 200: loss 2.302583
# Train with learning rate 1e-07 and regularization 0.001
# iteration 0 / 200: loss 2.302583
# iteration 100 / 200: loss 2.302603
# Train with learning rate 1e-07 and regularization 0.01
# iteration 0 / 200: loss 2.302614
# iteration 100 / 200: loss 2.302605
# Train with learning rate 1e-07 and regularization 0.1
# iteration 0 / 200: loss 2.302660
# iteration 100 / 200: loss 2.302663
# Train with learning rate 1e-07 and regularization 1
# iteration 0 / 200: loss 2.303326
# iteration 100 / 200: loss 2.303328
# Train with learning rate 1e-07 and regularization 10.0
# iteration 0 / 200: loss 2.310273
# iteration 100 / 200: loss 2.310291
# Train with learning rate 1e-07 and regularization 100.0
# iteration 0 / 200: loss 2.379331
# iteration 100 / 200: loss 2.379195
# Train with learning rate 1e-07 and regularization 1000.0
# iteration 0 / 200: loss 3.075347
# iteration 100 / 200: loss 3.060800
# Train with learning rate 1e-07 and regularization 10000.0
# iteration 0 / 200: loss 9.999256
# iteration 100 / 200: loss 8.666219
# Train with learning rate 5e-07 and regularization 0.0001
# iteration 0 / 200: loss 2.302589
# iteration 100 / 200: loss 2.302571
# Train with learning rate 5e-07 and regularization 0.001
# iteration 0 / 200: loss 2.302583
# iteration 100 / 200: loss 2.302569
# Train with learning rate 5e-07 and regularization 0.01
# iteration 0 / 200: loss 2.302566
# iteration 100 / 200: loss 2.302610
# Train with learning rate 5e-07 and regularization 0.1
# iteration 0 / 200: loss 2.302651
# iteration 100 / 200: loss 2.302640
# Train with learning rate 5e-07 and regularization 1
# iteration 0 / 200: loss 2.303356
# iteration 100 / 200: loss 2.303352
# Train with learning rate 5e-07 and regularization 10.0
# iteration 0 / 200: loss 2.310360
# iteration 100 / 200: loss 2.310364
# Train with learning rate 5e-07 and regularization 100.0
# iteration 0 / 200: loss 2.379662
# iteration 100 / 200: loss 2.378922
# Train with learning rate 5e-07 and regularization 1000.0
# iteration 0 / 200: loss 3.073364
# iteration 100 / 200: loss 3.003471
# Train with learning rate 5e-07 and regularization 10000.0
# iteration 0 / 200: loss 10.074253
# iteration 100 / 200: loss 5.299912
# :) BEST Validation Accuracy:  0.151
# Train with learning rate 1e-06 and regularization 0.0001
# iteration 0 / 200: loss 2.302597
# iteration 100 / 200: loss 2.302589
# Train with learning rate 1e-06 and regularization 0.001
# iteration 0 / 200: loss 2.302592
# iteration 100 / 200: loss 2.302594
# Train with learning rate 1e-06 and regularization 0.01
# iteration 0 / 200: loss 2.302583
# iteration 100 / 200: loss 2.302577
# Train with learning rate 1e-06 and regularization 0.1
# iteration 0 / 200: loss 2.302662
# iteration 100 / 200: loss 2.302671
# Train with learning rate 1e-06 and regularization 1
# iteration 0 / 200: loss 2.303354
# iteration 100 / 200: loss 2.303351
# Train with learning rate 1e-06 and regularization 10.0
# iteration 0 / 200: loss 2.310337
# iteration 100 / 200: loss 2.310313
# Train with learning rate 1e-06 and regularization 100.0
# iteration 0 / 200: loss 2.379571
# iteration 100 / 200: loss 2.378145
# Train with learning rate 1e-06 and regularization 1000.0
# iteration 0 / 200: loss 3.071353
# iteration 100 / 200: loss 2.938223
# Train with learning rate 1e-06 and regularization 10000.0
# iteration 0 / 200: loss 10.011894
# iteration 100 / 200: loss 3.444080
# Train with learning rate 5e-06 and regularization 0.0001
# iteration 0 / 200: loss 2.302607
# iteration 100 / 200: loss 2.302582
# Train with learning rate 5e-06 and regularization 0.001
# iteration 0 / 200: loss 2.302579
# iteration 100 / 200: loss 2.302558
# Train with learning rate 5e-06 and regularization 0.01
# iteration 0 / 200: loss 2.302593
# iteration 100 / 200: loss 2.302582
# Train with learning rate 5e-06 and regularization 0.1
# iteration 0 / 200: loss 2.302688
# iteration 100 / 200: loss 2.302678
# Train with learning rate 5e-06 and regularization 1
# iteration 0 / 200: loss 2.303373
# iteration 100 / 200: loss 2.303374
# Train with learning rate 5e-06 and regularization 10.0
# iteration 0 / 200: loss 2.310248
# iteration 100 / 200: loss 2.310201
# :) BEST Validation Accuracy:  0.165
# Train with learning rate 5e-06 and regularization 100.0
# iteration 0 / 200: loss 2.380010
# iteration 100 / 200: loss 2.372985
# Train with learning rate 5e-06 and regularization 1000.0
# iteration 0 / 200: loss 3.076614
# iteration 100 / 200: loss 2.601108
# Train with learning rate 5e-06 and regularization 10000.0
# iteration 0 / 200: loss 10.004952
# iteration 100 / 200: loss 2.303039
# Train with learning rate 1e-05 and regularization 0.0001
# iteration 0 / 200: loss 2.302599
# iteration 100 / 200: loss 2.302579
# :) BEST Validation Accuracy:  0.17
# Train with learning rate 1e-05 and regularization 0.001
# iteration 0 / 200: loss 2.302583
# iteration 100 / 200: loss 2.302561
# Train with learning rate 1e-05 and regularization 0.01
# iteration 0 / 200: loss 2.302596
# iteration 100 / 200: loss 2.302563
# Train with learning rate 1e-05 and regularization 0.1
# iteration 0 / 200: loss 2.302654
# iteration 100 / 200: loss 2.302636
# Train with learning rate 1e-05 and regularization 1
# iteration 0 / 200: loss 2.303373
# iteration 100 / 200: loss 2.303310
# Train with learning rate 1e-05 and regularization 10.0
# iteration 0 / 200: loss 2.310269
# iteration 100 / 200: loss 2.310137
# Train with learning rate 1e-05 and regularization 100.0
# iteration 0 / 200: loss 2.380111
# iteration 100 / 200: loss 2.366673
# Train with learning rate 1e-05 and regularization 1000.0
# iteration 0 / 200: loss 3.070381
# iteration 100 / 200: loss 2.416271
# Train with learning rate 1e-05 and regularization 10000.0
# iteration 0 / 200: loss 9.987347
# iteration 100 / 200: loss 2.302585
# lr 1.000000e-08 reg 1.000000e-04 train accuracy: 0.108333 val accuracy: 0.085000
# lr 1.000000e-08 reg 1.000000e-03 train accuracy: 0.139937 val accuracy: 0.129000
# lr 1.000000e-08 reg 1.000000e-02 train accuracy: 0.072083 val accuracy: 0.072000
# lr 1.000000e-08 reg 1.000000e-01 train accuracy: 0.079812 val accuracy: 0.079000
# lr 1.000000e-08 reg 1.000000e+00 train accuracy: 0.078396 val accuracy: 0.058000
# lr 1.000000e-08 reg 1.000000e+01 train accuracy: 0.112333 val accuracy: 0.104000
# lr 1.000000e-08 reg 1.000000e+02 train accuracy: 0.106313 val accuracy: 0.102000
# lr 1.000000e-08 reg 1.000000e+03 train accuracy: 0.140854 val accuracy: 0.146000
# lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.094167 val accuracy: 0.089000
# lr 5.000000e-08 reg 1.000000e-04 train accuracy: 0.100458 val accuracy: 0.084000
# lr 5.000000e-08 reg 1.000000e-03 train accuracy: 0.105063 val accuracy: 0.100000
# lr 5.000000e-08 reg 1.000000e-02 train accuracy: 0.088563 val accuracy: 0.080000
# lr 5.000000e-08 reg 1.000000e-01 train accuracy: 0.117854 val accuracy: 0.130000
# lr 5.000000e-08 reg 1.000000e+00 train accuracy: 0.145042 val accuracy: 0.147000
# lr 5.000000e-08 reg 1.000000e+01 train accuracy: 0.089917 val accuracy: 0.091000
# lr 5.000000e-08 reg 1.000000e+02 train accuracy: 0.125854 val accuracy: 0.124000
# lr 5.000000e-08 reg 1.000000e+03 train accuracy: 0.083625 val accuracy: 0.087000
# lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.087833 val accuracy: 0.076000
# lr 1.000000e-07 reg 1.000000e-04 train accuracy: 0.088500 val accuracy: 0.087000
# lr 1.000000e-07 reg 1.000000e-03 train accuracy: 0.110083 val accuracy: 0.105000
# lr 1.000000e-07 reg 1.000000e-02 train accuracy: 0.086042 val accuracy: 0.078000
# lr 1.000000e-07 reg 1.000000e-01 train accuracy: 0.096229 val accuracy: 0.096000
# lr 1.000000e-07 reg 1.000000e+00 train accuracy: 0.123146 val accuracy: 0.123000
# lr 1.000000e-07 reg 1.000000e+01 train accuracy: 0.086667 val accuracy: 0.084000
# lr 1.000000e-07 reg 1.000000e+02 train accuracy: 0.094958 val accuracy: 0.104000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.089417 val accuracy: 0.088000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.099187 val accuracy: 0.101000
# lr 5.000000e-07 reg 1.000000e-04 train accuracy: 0.118667 val accuracy: 0.127000
# lr 5.000000e-07 reg 1.000000e-03 train accuracy: 0.091313 val accuracy: 0.081000
# lr 5.000000e-07 reg 1.000000e-02 train accuracy: 0.085687 val accuracy: 0.091000
# lr 5.000000e-07 reg 1.000000e-01 train accuracy: 0.103083 val accuracy: 0.102000
# lr 5.000000e-07 reg 1.000000e+00 train accuracy: 0.103417 val accuracy: 0.099000
# lr 5.000000e-07 reg 1.000000e+01 train accuracy: 0.098812 val accuracy: 0.106000
# lr 5.000000e-07 reg 1.000000e+02 train accuracy: 0.077083 val accuracy: 0.089000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.091708 val accuracy: 0.086000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.150875 val accuracy: 0.151000
# lr 1.000000e-06 reg 1.000000e-04 train accuracy: 0.101417 val accuracy: 0.118000
# lr 1.000000e-06 reg 1.000000e-03 train accuracy: 0.110208 val accuracy: 0.113000
# lr 1.000000e-06 reg 1.000000e-02 train accuracy: 0.095854 val accuracy: 0.103000
# lr 1.000000e-06 reg 1.000000e-01 train accuracy: 0.100562 val accuracy: 0.098000
# lr 1.000000e-06 reg 1.000000e+00 train accuracy: 0.110521 val accuracy: 0.114000
# lr 1.000000e-06 reg 1.000000e+01 train accuracy: 0.090292 val accuracy: 0.082000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.089146 val accuracy: 0.092000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.072542 val accuracy: 0.073000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.107042 val accuracy: 0.106000
# lr 5.000000e-06 reg 1.000000e-04 train accuracy: 0.115667 val accuracy: 0.105000
# lr 5.000000e-06 reg 1.000000e-03 train accuracy: 0.121813 val accuracy: 0.133000
# lr 5.000000e-06 reg 1.000000e-02 train accuracy: 0.138792 val accuracy: 0.149000
# lr 5.000000e-06 reg 1.000000e-01 train accuracy: 0.099604 val accuracy: 0.089000
# lr 5.000000e-06 reg 1.000000e+00 train accuracy: 0.117062 val accuracy: 0.128000
# lr 5.000000e-06 reg 1.000000e+01 train accuracy: 0.159750 val accuracy: 0.165000
# lr 5.000000e-06 reg 1.000000e+02 train accuracy: 0.154812 val accuracy: 0.157000
# lr 5.000000e-06 reg 1.000000e+03 train accuracy: 0.153688 val accuracy: 0.156000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.100625 val accuracy: 0.092000
# lr 1.000000e-05 reg 1.000000e-04 train accuracy: 0.155479 val accuracy: 0.170000
# lr 1.000000e-05 reg 1.000000e-03 train accuracy: 0.122667 val accuracy: 0.133000
# lr 1.000000e-05 reg 1.000000e-02 train accuracy: 0.144500 val accuracy: 0.133000
# lr 1.000000e-05 reg 1.000000e-01 train accuracy: 0.152604 val accuracy: 0.153000
# lr 1.000000e-05 reg 1.000000e+00 train accuracy: 0.158792 val accuracy: 0.158000
# lr 1.000000e-05 reg 1.000000e+01 train accuracy: 0.165229 val accuracy: 0.164000
# lr 1.000000e-05 reg 1.000000e+02 train accuracy: 0.148938 val accuracy: 0.159000
# lr 1.000000e-05 reg 1.000000e+03 train accuracy: 0.114229 val accuracy: 0.099000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.101292 val accuracy: 0.093000
# best validation accuracy achieved during validation: 0.170000

# %%
# visualize the weights of the best network
show_net_weights(best_net)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-92183bf1948b> in <module>()
#       1 # visualize the weights of the best network
# ----> 2 show_net_weights(best_net)
#
# <ipython-input-14-43ead7e9a195> in show_net_weights(net)
#       5 def show_net_weights(net):
#       6     fig = plt.figure(figsize=(20,20))
# ----> 7     W1 = net.params['W1']
#       8     W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
#       9     plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
#
# AttributeError: 'NoneType' object has no attribute 'params'

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Inline Question</h3>
#     <p>Describe what your visualized two-layer-net weights look like, in particular in contrast to the softmax weights of the first exercise of this set.</p>
# </div>

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.

# %%
from dl4cv.model_savers import save_two_layer_net
save_two_layer_net(best_net)

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#
# $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.5 \\
#         \left(\frac{50}{\exp(0.5 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.5 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.5, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
